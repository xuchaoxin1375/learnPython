# %%
import numpy as np
from numpy import random

# %%
np.exp(1)
# Out:
# 2.718281828459045

# %%
a=np.arange(1,4)
print(a)
# Out:
# [1 2 3]

# %%
np.exp(a)
# Out:
# array([ 2.71828183,  7.3890561 , 20.08553692])

# %%
b=np.array(np.arange(1,4))
print(b)
# Out:
# [1 2 3]

# %%
np.exp(b)
# Out:
# array([ 2.71828183,  7.3890561 , 20.08553692])

# %%
np.exp(b)+np.exp(b)
# Out:
# array([ 5.43656366, 14.7781122 , 40.17107385])

# %%
# A=random.uniform(-1,1,10000)
# print(A)
random.normal(size=10000)
# Out:
# array([-0.87868504, -0.30282191, -0.10004509, ...,  0.73729099,
#        -0.27255975, -2.01425912])

# %%
print("exp(A)+exp(B)=",np.exp(A)+np.exp(B))
# Out:
# exp(A)+exp(B)= [inf inf inf ... inf inf inf]
# <ipython-input-75-75f4d7f9aeb5>:1: RuntimeWarning: overflow encountered in exp
#   print("exp(A)+exp(B)=",np.exp(A)+np.exp(B))

# %%
a=random.randint(5,7,(4,4))
print(a)
# Out:
# [[6 5 5 6]
#  [5 5 6 6]
#  [6 5 5 5]
#  [6 5 6 6]]

# %%
a.mean(axis=1)
# Out:
# array([5.5 , 5.5 , 5.25, 5.75])

# %%
a
# Out:
# array([[6, 5, 5, 6],
#        [5, 5, 6, 6],
#        [6, 5, 5, 5],
#        [6, 5, 6, 6]])

# %%
a-a.mean(axis=1).reshape(4,1)
# Out:
# array([[ 0.5 , -0.5 , -0.5 ,  0.5 ],
#        [-0.5 , -0.5 ,  0.5 ,  0.5 ],
#        [ 0.75, -0.25, -0.25, -0.25],
#        [ 0.25, -0.75,  0.25,  0.25]])

# %%
a.mean(axis=1).reshape(4,1).shape
# Out:
# (4, 1)

# %%
import scipy

# %%
def f(x):
    return x**2+np.math.sin(x)+math.sqrt(x)+x**(1/3)+1
print('integration:',scipy.integrate.quad(f,1,2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-e7ebddc6ce9a> in <module>
#       1 def f(x):
#       2     return x**2+np.math.sin(x)+math.sqrt(x)+x**(1/3)+1
# ----> 3 print('integration:',scipy.integrate.quad(f,1,2))
#
# AttributeError: module 'scipy' has no attribute 'integrate'

# %%
import numpy as np  
import matplotlib.pyplot as plt  
  
mu,sigma=100,15  
x=mu+sigma*np.random.randn(10000)  
num_bins=50
fig,ax=plt.subplots()
n,bins,patches=ax.hist(x,num_bins,density=True)  

plt.xlabel('Smarts')  
plt.ylabel('Probability')  
plt.title('Histogram of IQ')  
plt.text(60,.025, r'$\mu=100,\ \sigma=15$')  
plt.axis([40,160,0,0.03])  
plt.grid(True)

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Nov 03 15:23:57 2016

@author: gsdx
"""

import numpy as np  
import matplotlib.pyplot as plt  
  
mu,sigma=100,15  
x=mu+sigma*np.random.randn(10000)  
num_bins=50
fig,ax=plt.subplots()
n,bins,patches=plt.get_plot_commands().hist(x,num_bins,density=True)  
plt.xlabel('Smarts')  
plt.ylabel('Probability')  
plt.title('Histogram of IQ')  
plt.text(60,.025, r'$\mu=100,\ \sigma=15$')  
plt.axis([40,160,0,0.03])  
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-07b43f724a6c> in <module>
#      13 num_bins=50
#      14 fig,ax=plt.subplots()
# ---> 15 n,bins,patches=plt.get_plot_commands().hist(x,num_bins,density=True)
#      16 plt.xlabel('Smarts')
#      17 plt.ylabel('Probability')
#
# AttributeError: 'list' object has no attribute 'hist'

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Nov 03 15:23:57 2016

@author: gsdx
"""

import numpy as np  
import matplotlib.pyplot as plt  
  
mu,sigma=100,15  
x=mu+sigma*np.random.randn(10000)  
  
n,bins,patches=plt.hist(x,50,density=1,facecolor='g',alpha=0.75)  
plt.xlabel('Smarts')  
plt.ylabel('Probability')  
plt.title('Histogram of IQ')  
plt.text(60,.025, r'$\mu=100,\ \sigma=15$')  
plt.axis([40,160,0,0.03])  
plt.grid(True)
