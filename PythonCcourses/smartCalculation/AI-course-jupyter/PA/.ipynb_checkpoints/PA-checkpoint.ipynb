# %%
from IPython.display import Image
Image(filename='1.png')

# %%
Image(filename='2.png')

# %%
Image(filename='3.png')

# %%
Image(filename='4.png')

# %%
Image(filename='5.jpg')

# %%
Image(filename='6.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
 
 
class PSO(object):
    def __init__(self, population_size, max_steps):
        self.w = 0.6  # 惯性权重
        self.c1 = self.c2 = 2
        self.population_size = population_size  # 粒子群数量
        self.dim = 2  # 搜索空间的维度
        self.max_steps = max_steps  # 迭代次数
        self.x_bound = [-10, 10]  # 解空间范围
        self.x = np.random.uniform(self.x_bound[0], self.x_bound[1],
                                   (self.population_size, self.dim))  # 初始化粒子群位置
        self.v = np.random.rand(self.population_size, self.dim)  # 初始化粒子群速度
        fitness = self.calculate_fitness(self.x)
        self.p = self.x  # 个体的最佳位置
        self.pg = self.x[np.argmin(fitness)]  # 全局最佳位置
        self.individual_best_fitness = fitness  # 个体的最优适应度
        self.global_best_fitness = np.min(fitness)  # 全局最佳适应度
 
    def calculate_fitness(self, x):
        return np.sum(np.square(x), axis=1)
 
    def evolve(self):
        fig = plt.figure()
        for step in range(self.max_steps):
            r1 = np.random.rand(self.population_size, self.dim)
            r2 = np.random.rand(self.population_size, self.dim)
            # 更新速度和权重
            self.v = self.w*self.v+self.c1*r1*(self.p-self.x)+self.c2*r2*(self.pg-self.x)
            self.x = self.v + self.x
            plt.clf()
            plt.scatter(self.x[:, 0], self.x[:, 1], s=30, color='k')
            plt.xlim(self.x_bound[0], self.x_bound[1])
            plt.ylim(self.x_bound[0], self.x_bound[1])
            plt.pause(0.01)
            fitness = self.calculate_fitness(self.x)
            # 需要更新的个体
            update_id = np.greater(self.individual_best_fitness, fitness)
            self.p[update_id] = self.x[update_id]
            self.individual_best_fitness[update_id] = fitness[update_id]
            # 新一代出现了更小的fitness，所以更新全局最优fitness和位置
            if np.min(fitness) < self.global_best_fitness:
                self.pg = self.x[np.argmin(fitness)]
                self.global_best_fitness = np.min(fitness)
            print('best fitness: %.5f, mean fitness: %.5f' % (self.global_best_fitness, np.mean(fitness)))
 
 
pso = PSO(100, 100)
pso.evolve()
plt.show()
# Out:
# best fitness: 0.00369, mean fitness: 23.83374
# best fitness: 0.00369, mean fitness: 34.82536
# best fitness: 0.00369, mean fitness: 29.75863
# best fitness: 0.00369, mean fitness: 29.50772
# best fitness: 0.00369, mean fitness: 29.24587
# best fitness: 0.00369, mean fitness: 21.20637
# best fitness: 0.00369, mean fitness: 23.77637
# best fitness: 0.00369, mean fitness: 18.35243
# best fitness: 0.00369, mean fitness: 15.26676
# best fitness: 0.00369, mean fitness: 27.74193
# best fitness: 0.00369, mean fitness: 28.66992
# best fitness: 0.00369, mean fitness: 13.33578
# best fitness: 0.00369, mean fitness: 23.23498
# best fitness: 0.00101, mean fitness: 29.28025
# best fitness: 0.00101, mean fitness: 24.24420
# best fitness: 0.00101, mean fitness: 18.81175
# best fitness: 0.00008, mean fitness: 27.46523
# best fitness: 0.00008, mean fitness: 17.00286
# best fitness: 0.00008, mean fitness: 13.56154
# best fitness: 0.00008, mean fitness: 19.07583
# best fitness: 0.00008, mean fitness: 32.82432
# best fitness: 0.00008, mean fitness: 14.25537
# best fitness: 0.00008, mean fitness: 5.28750
# best fitness: 0.00008, mean fitness: 8.78405
# best fitness: 0.00008, mean fitness: 6.82553
# best fitness: 0.00008, mean fitness: 4.09008
# best fitness: 0.00007, mean fitness: 7.97128
# best fitness: 0.00007, mean fitness: 4.16062
# best fitness: 0.00007, mean fitness: 8.98426
# best fitness: 0.00000, mean fitness: 6.29503
# best fitness: 0.00000, mean fitness: 5.51509
# best fitness: 0.00000, mean fitness: 2.42008
# best fitness: 0.00000, mean fitness: 4.31859
# best fitness: 0.00000, mean fitness: 2.22465
# best fitness: 0.00000, mean fitness: 4.61514
# best fitness: 0.00000, mean fitness: 2.79024
# best fitness: 0.00000, mean fitness: 2.12509
# best fitness: 0.00000, mean fitness: 1.53421
# best fitness: 0.00000, mean fitness: 2.85513
# best fitness: 0.00000, mean fitness: 1.36736
# best fitness: 0.00000, mean fitness: 1.13718
# best fitness: 0.00000, mean fitness: 0.63938
# best fitness: 0.00000, mean fitness: 1.06627
# best fitness: 0.00000, mean fitness: 0.49661
# best fitness: 0.00000, mean fitness: 0.81960
# best fitness: 0.00000, mean fitness: 0.53209
# best fitness: 0.00000, mean fitness: 0.33924
# best fitness: 0.00000, mean fitness: 0.52835
# best fitness: 0.00000, mean fitness: 1.16571
# best fitness: 0.00000, mean fitness: 0.65017
# best fitness: 0.00000, mean fitness: 1.16970
# best fitness: 0.00000, mean fitness: 0.48852
# best fitness: 0.00000, mean fitness: 0.23483
# best fitness: 0.00000, mean fitness: 0.44098
# best fitness: 0.00000, mean fitness: 0.16980
# best fitness: 0.00000, mean fitness: 0.23696
# best fitness: 0.00000, mean fitness: 0.46408
# best fitness: 0.00000, mean fitness: 0.24801
# best fitness: 0.00000, mean fitness: 0.27802
# best fitness: 0.00000, mean fitness: 0.10835
# best fitness: 0.00000, mean fitness: 0.50976
# best fitness: 0.00000, mean fitness: 0.65585
# best fitness: 0.00000, mean fitness: 1.89028
# best fitness: 0.00000, mean fitness: 7.47364
# best fitness: 0.00000, mean fitness: 0.77734
# best fitness: 0.00000, mean fitness: 0.28440
# best fitness: 0.00000, mean fitness: 0.84841
# best fitness: 0.00000, mean fitness: 0.12378
# best fitness: 0.00000, mean fitness: 0.47537
# best fitness: 0.00000, mean fitness: 0.14812
# best fitness: 0.00000, mean fitness: 0.08154
# best fitness: 0.00000, mean fitness: 0.07805
# best fitness: 0.00000, mean fitness: 0.10446
# best fitness: 0.00000, mean fitness: 0.05295
# best fitness: 0.00000, mean fitness: 0.03691
# best fitness: 0.00000, mean fitness: 0.01126
# best fitness: 0.00000, mean fitness: 0.03674
# best fitness: 0.00000, mean fitness: 0.00622
# best fitness: 0.00000, mean fitness: 0.01379
# best fitness: 0.00000, mean fitness: 0.02577
# best fitness: 0.00000, mean fitness: 0.01144
# best fitness: 0.00000, mean fitness: 0.02030
# best fitness: 0.00000, mean fitness: 0.01925
# best fitness: 0.00000, mean fitness: 0.01844
# best fitness: 0.00000, mean fitness: 0.00743
# best fitness: 0.00000, mean fitness: 0.00810
# best fitness: 0.00000, mean fitness: 0.00826
# best fitness: 0.00000, mean fitness: 0.01115
# best fitness: 0.00000, mean fitness: 0.00986
# best fitness: 0.00000, mean fitness: 0.01175
# best fitness: 0.00000, mean fitness: 0.00781
# best fitness: 0.00000, mean fitness: 0.02138
# best fitness: 0.00000, mean fitness: 0.02700
# best fitness: 0.00000, mean fitness: 0.02708
# best fitness: 0.00000, mean fitness: 0.00749
# best fitness: 0.00000, mean fitness: 0.00367
# best fitness: 0.00000, mean fitness: 0.00870
# best fitness: 0.00000, mean fitness: 0.00171
# best fitness: 0.00000, mean fitness: 0.00515
# best fitness: 0.00000, mean fitness: 0.00074
