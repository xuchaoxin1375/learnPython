# %%
import cv2
import os
import time
from IPython.display import clear_output
from genetic_drawing import *

# %%
#load the example image and set the generator for 100 stages with 20 generations each
gen = GeneticDrawing('example.jpg', seed=time.time())
out = gen.generate(100, 20)
# Out:
# Stage  37 . Generation  19 / 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8170db9ec18e> in <module>
#       1 #load the example image and set the generator for 100 stages with 20 generations each
#       2 gen = GeneticDrawing('example.jpg', seed=time.time())
# ----> 3 out = gen.generate(100, 20)
#
# ~/Documents/jupyter_notebook/course/genetic-drawing-master/genetic_drawing.py in generate(self, stages, generations, brushstrokesCount, show_progress_imgs)
#      35             #evolve DNA
#      36             for g in range(generations):
# ---> 37                 self.myDNA.evolveDNASeq(self.img_grey, self.seed + time.time() + g)
#      38                 clear_output(wait=True)
#      39                 print("Stage ", s+1, ". Generation ", g+1, "/", generations)
#
# ~/Documents/jupyter_notebook/course/genetic-drawing-master/genetic_drawing.py in evolveDNASeq(self, inImg, seed)
#     339     def evolveDNASeq(self, inImg, seed):
#     340         for i in range(len(self.DNASeq)):
# --> 341             self.__evolveDNA(i, inImg, seed)
#
# ~/Documents/jupyter_notebook/course/genetic-drawing-master/genetic_drawing.py in __evolveDNA(self, index, inImg, seed)
#     313                 #print('new color: ', child[0])
#     314             elif changeIndex == 1 or changeIndex == 2:#if pos Y or X
# --> 315                 child[1], child[2] = self.gen_new_positions()
#     316                 #print('new posY: ', child[1], ' / ', self.bound[0])
#     317                 #print('new posX: ', child[2],  ' / ', self.bound[1])
#
# ~/Documents/jupyter_notebook/course/genetic-drawing-master/genetic_drawing.py in gen_new_positions(self)
#     147     def gen_new_positions(self):
#     148         if self.sampling_mask is not None:
# --> 149             pos = util_sample_from_img(self.sampling_mask)
#     150             posY = pos[0][0]
#     151             posX = pos[1][0]
#
# ~/Documents/jupyter_notebook/course/genetic-drawing-master/genetic_drawing.py in util_sample_from_img(img)
#     110     pos = pos.reshape(2, pos.shape[1]*pos.shape[2])
#     111     img_flat = np.clip(img.flatten() / img.flatten().sum(), 0.0, 1.0)
# --> 112     return pos[:, np.random.choice(np.arange(pos.shape[1]), 1, p=img_flat)]
#     113
#     114 class DNA:
#
# KeyboardInterrupt:

# %%
#load a custom mask and set a smaller brush size for finer details
gen.sampling_mask = cv2.cvtColor(cv2.imread("mask.jpg"), cv2.COLOR_BGR2GRAY)
gen.brushesRange = [[0.05, 0.1], [0.1, 0.2]]
#keep drawing on top of our previous result
out = gen.generate(40, 30)
# Out:
# Stage  1 . Generation  8 / 30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-c2eb56bc1b13> in <module>
#       3 gen.brushesRange = [[0.05, 0.1], [0.1, 0.2]]
#       4 #keep drawing on top of our previous result
# ----> 5 out = gen.generate(40, 30)
#
# ~/Documents/jupyter_notebook/course/genetic-drawing-master/genetic_drawing.py in generate(self, stages, generations, brushstrokesCount, show_progress_imgs)
#      35             #evolve DNA
#      36             for g in range(generations):
# ---> 37                 self.myDNA.evolveDNASeq(self.img_grey, self.seed + time.time() + g)
#      38                 clear_output(wait=True)
#      39                 print("Stage ", s+1, ". Generation ", g+1, "/", generations)
#
# ~/Documents/jupyter_notebook/course/genetic-drawing-master/genetic_drawing.py in evolveDNASeq(self, inImg, seed)
#     339     def evolveDNASeq(self, inImg, seed):
#     340         for i in range(len(self.DNASeq)):
# --> 341             self.__evolveDNA(i, inImg, seed)
#
# ~/Documents/jupyter_notebook/course/genetic-drawing-master/genetic_drawing.py in __evolveDNA(self, index, inImg, seed)
#     313                 #print('new color: ', child[0])
#     314             elif changeIndex == 1 or changeIndex == 2:#if pos Y or X
# --> 315                 child[1], child[2] = self.gen_new_positions()
#     316                 #print('new posY: ', child[1], ' / ', self.bound[0])
#     317                 #print('new posX: ', child[2],  ' / ', self.bound[1])
#
# ~/Documents/jupyter_notebook/course/genetic-drawing-master/genetic_drawing.py in gen_new_positions(self)
#     147     def gen_new_positions(self):
#     148         if self.sampling_mask is not None:
# --> 149             pos = util_sample_from_img(self.sampling_mask)
#     150             posY = pos[0][0]
#     151             posX = pos[1][0]
#
# ~/Documents/jupyter_notebook/course/genetic-drawing-master/genetic_drawing.py in util_sample_from_img(img)
#     109     pos = np.indices(dimensions=img.shape)
#     110     pos = pos.reshape(2, pos.shape[1]*pos.shape[2])
# --> 111     img_flat = np.clip(img.flatten() / img.flatten().sum(), 0.0, 1.0)
#     112     return pos[:, np.random.choice(np.arange(pos.shape[1]), 1, p=img_flat)]
#     113
#
# KeyboardInterrupt:

# %%
#save all the images from the image buffer
if not os.path.exists('out'):
    os.mkdir("out")
for i in range(len(gen.imgBuffer)):
    cv2.imwrite(os.path.join("out", f"{i:06d}.png"), gen.imgBuffer[i])
#if you want to save only last image, run below
# cv2.imwrite("out/final.png', out)
